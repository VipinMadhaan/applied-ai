# %% [markdown]
# Let's create an empty set

# %%
is_this_a_set = {}
is_this_a_set
# Out:
# {}

# %%
type(is_this_a_set)
# Out:
# dict

# %%
empty_set = set()
empty_set
# Out:
# set()

# %%
type(empty_set)
# Out:
# set

# %% [markdown]
# Let's create a set with values

# %%
my_set = {1, 2, 3, 4}
my_set
# Out:
# {1, 2, 3, 4}

# %%
type(my_set)
# Out:
# set

# %%
my_other_set = {9, 2, 7, 4, 0, 1}
my_other_set  # note that the output may seem ordered, but this isn't guaranteed by Python
# Out:
# {0, 1, 2, 4, 7, 9}

# %%
set(range(1, 10))
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
set([1, 1, 2, 2, 2, 8, 8, 8, 3, 4])  # sets remove duplicate values; this is a good way to get uniques from sequences
# Out:
# {1, 2, 3, 4, 8}

# %%
set('Hello world!')
# Out:
# {' ', '!', 'H', 'd', 'e', 'l', 'o', 'r', 'w'}

# %%
# my_set[1]  # sets aren't indexable as they do not inherently have an order

# %%
# {1, 2, 3, {'a', 'b', 'c'}}  # nested sets are impossible as sets must contain immutable, hashable values
