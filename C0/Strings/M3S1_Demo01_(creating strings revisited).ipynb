# %% [markdown]
# A string is a data type which is often used to store textual data. We can
#
# 1.   List item
# 2.   List item
#
# assign strings to variables.

# %%
empty_str = ''

# %%
empty_str
# Out:
# ''

# %%
print(empty_str)

# %%
type(empty_str)
# Out:
# str

# %%
character = 'h'

# %%
character
# Out:
# 'h'

# %%
print(character)
# Out:
# h

# %%
type(character)
# Out:
# str

# %%
word = 'Hello'

# %%
word
# Out:
# 'Hello'

# %%
sentence = 'Hello world!'

# %%
sentence
# Out:
# 'Hello world!'

# %% [markdown]
# We can assign strings using single or double quotes
#
# ---

# %%
str1 = "abc"
str2 = 'abc'

# %%
str1
# Out:
# 'abc'

# %%
str2
# Out:
# 'abc'

# %%
# Checking the equality of the two strings to see if they're storing the same value
str1 == str2
# Out:
# True

# %%
# Quotes can be included within string
single_quoted_str = "'Python'"
double_quoted_str = '"Python"'

# %%
single_quoted_str
# Out:
# "'Python'"

# %%
print(single_quoted_str)
# Out:
# 'Python'

# %%
double_quoted_str
# Out:
# '"Python"'

# %%
print(double_quoted_str)
# Out:
# "Python"

# %%
single_quoted_str == double_quoted_str
# Out:
# False

# %%
# you_are = 'you're'

# %%
you_are = "you're"

# %%
you_are
# Out:
# "you're"

# %% [markdown]
# We can also create multi-line strings

# %%
multi_line_string = '''
This string
spans many
lines!
'''

# %%
multi_line_string  # every line of the multi-line string is separated by the escape sequence '\n' which represents a new line
# Out:
# '\nThis string\nspans many\nlines!\n'

# %% [markdown]
# We can use the `str()` function to create strings or to typecast other data types to string

# %%
a = str(25)

# %%
type(a)
# Out:
# str

# %%
a
# Out:
# '25'
