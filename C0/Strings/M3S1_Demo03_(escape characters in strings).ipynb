# %% [markdown]
# **Escape characters** are used to represent characters which would be otherwise difficult to include directly in a string

# %%
# print('I'm sad')

# %%
print('I\'m sad')
# Out:
# I'm sad

# %%
print("I'm sad")
# Out:
# I'm sad

# %%
# print("She said, "hey now!"")

# %%
print("She said, \"hey now!\"")
# Out:
# She said, "hey now!"

# %%
print('She said, "hey now!"')
# Out:
# She said, "hey now!"

# %%
# greeting = 'Hello
# World'

# %%
greeting = 'Hello\nWorld!'  # newline (line-break)

# %%
greeting
# Out:
# 'Hello\nWorld!'

# %%
print(greeting)
# Out:
# Hello
# World!

# %%
greeting2 = '''Hello
World!'''

# %%
greeting2
# Out:
# 'Hello\nWorld!'

# %%
print(greeting2)
# Out:
# Hello
# World!

# %%
print('Col 1\tCol 2')  # horizontal tab
# Out:
# Col 1	Col 2

# %%
print('Filepath: My Computer\C:\newfolder')  # the second backslash here is being read as '\n'
# Out:
# Filepath: My Computer\C:
# ewfolder

# %%
print('Filepath: My Computer\\C:\\Python Projects')  # backslash
# Out:
# Filepath: My Computer\C:\Python Projects
