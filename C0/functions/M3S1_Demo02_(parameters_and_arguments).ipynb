# %% [markdown]
# **Parameters** are variables that a function takes as input when it is called. Parameters act as placeholders for the values (**arguments**) that will be passed to the function when it is called.

# %%
def find_sum(a, b): return a + b

# %%
print(find_sum(a = 1, b = 2))
# Out:
# 3

# %%
def repeat_string(string, times): return string * times

# %%
x = repeat_string(string = 'Hello', times = 3)
print(x)
# Out:
# HelloHelloHello

# %% [markdown]
# When parameters aren't provided, the arguments passed to the function are passed in order of the parameter declaration within the function

# %%
print(find_sum(10, 20))  # here, 10 and 20 are arguments passed to the function for parameters a and b respectively
# Out:
# 30

# %%
y = repeat_string('ha', 20)  # here, 'ha' and 20 are arguments passed to the function for parameters string and times respectively
print(y)
# Out:
# hahahahahahahahahahahahahahahahahahahaha

# %% [markdown]
# Default arguments can be set for parameters

# %%
def calculate(a, b, operation = 'add'):  # parameters with default arguments must be defined after parameters without default arguments
    if operation == 'add': return a + b
    elif operation == 'sub': return a - b
    else: return '<unknown operation>'

# %%
op_1 = calculate(1, 2, 'add')
op_2 = calculate(1, 2)  # resorts to default argument
op_3 = calculate(1, 2, 'sub')
op_4 = calculate(1, 2, 'mul')

print(op_1, op_2, op_3, op_4)
# Out:
# 3 3 -1 <unknown operation>
